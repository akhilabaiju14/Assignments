# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset

# %%
data=pd.read_csv('iris.csv')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Display columns in the Dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Mean of each column of the dataset

# %%
np.mean(data[data.columns])
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Checking for the null values present in the dataset

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Visualizations using the dataset

# %% [markdown]
# Sepal_width vs sepal_length

# %%
plt.figure(figsize=(6,4))
plt.scatter(data['SL'],data['SW'],s=10)
plt.title('plot of Sepal_length vs Sepal_width')
plt.xlabel('SL')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
data1 = data[data['Classification'] == 'Iris-setosa']
plt.scatter(data1['PL'],data1['PW'],label='Iris-setosa',s=14,c='red',marker='*')
data1 = data[data['Classification'] == 'Iris-virginica']
plt.scatter(data1['PL'],data1['PW'],label='Iris-virginica',s=14,c='blue',marker='*')
data1 = data[data['Classification'] == 'Iris-versicolor']
plt.scatter(data1['PL'],data1['PW'],label='Iris-versicolor',s=14,c='green',marker='*')
plt.title('plot of Petal length vs petal width',fontsize=10)
plt.xlabel('PL',fontsize=10)
plt.ylabel('PW',fontsize=10)

plt.subplot(2,1,2)
data1 = data[data['Classification'] == 'Iris-setosa']
plt.scatter(data1['SL'],data1['SW'],s=14,label='Iris-setosa',c='red',marker='*')
data1 = data[data['Classification'] == 'Iris-virginica']
plt.scatter(data1['SL'],data1['SW'],s=14,label='Iris-virginica',c='blue',marker='*')
data1 = data[data['Classification'] == 'Iris-versicolor']
plt.scatter(data1['SL'],data1['SW'],s=14,label='Iris-versicolor',c='green',marker='*')
plt.title('plot of Sepal length vs Sepal width',fontsize=10)
plt.xlabel('SL',fontsize=10)
plt.ylabel('SW',fontsize=10)

plt.tight_layout()

# %%
plt.figure(figsize=(8,6))
sns.stripplot(x='Classification',y='PL',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PL'>

# %%
sns.violinplot(x='Classification',y='SL',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SL'>

# %%
sns.countplot(data['Classification'])
# Out:
# C:\software\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Classification', ylabel='count'>

# %%
sns.lmplot(x='PL', y='PW', data=data, hue='Classification', fit_reg=False)
